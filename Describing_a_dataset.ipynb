# %% [markdown]
# <a href="https://colab.research.google.com/github/MojubaAfo/Machine-learning-/blob/main/Describing_a_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ca86acde-bc86-41e6-9d9a-ccc55cfd774a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca86acde-bc86-41e6-9d9a-ccc55cfd774a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Doc = uploaded

# %%
data =pd.read_excel("BrandEquity_student_copy.xlsx")

# %%
df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   BL      999 non-null    float64
#  1   BAS     999 non-null    float64
#  2   BAW     999 non-null    float64
#  3   PQ      999 non-null    float64
#  4   OBE     999 non-null    float64
# dtypes: float64(5)
# memory usage: 39.1 KB

# %%
df.shape
# Out:
# (999, 5)

# %%
df.describe().transpose()
# Out:
#      count      mean       std  min       25%       50%       75%  max
# BL   999.0  4.865265  1.593041  1.0  3.800000  5.400000  6.000000  7.0
# BAS  999.0  5.062312  1.584283  1.0  4.250000  5.500000  6.250000  7.0
# BAW  999.0  4.738739  1.712961  1.0  4.000000  5.000000  6.000000  7.0
# PQ   999.0  5.343677  1.516408  1.0  5.000000  6.000000  6.000000  7.0
# OBE  999.0  4.253921  1.463704  1.0  3.333333  4.333333  5.333333  7.0

# %%
df.BL.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.BAS.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.BAW.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.OBE.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.PQ.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.scatter(x="OBE", y="PQ")
# Out:
# <Axes: xlabel='OBE', ylabel='PQ'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.skew()
# Out:
# BL    -0.680116
# BAS   -0.894351
# BAW   -0.516074
# PQ    -1.215481
# OBE   -0.321605
# dtype: float64

# %%
df.kurtosis()
# Out:
# BL    -0.570401
# BAS   -0.102223
# BAW   -0.887712
# PQ     0.545677
# OBE   -0.821672
# dtype: float64
